# %%
# Update to transformers 2.8.0
# !pip install -q transformers --upgrade
# !pip install -q pandas --upgrade
# !pip show transformers
# Out:
# ERROR: pandas-profiling 2.5.0 has requirement pandas==0.25.3, but you'll have pandas 1.0.3 which is incompatible.
# ERROR: hypertools 0.6.2 has requirement scikit-learn<0.22,>=0.19.1, but you'll have scikit-learn 0.22.2.post1 which is incompatible.
# Name: transformers
# Version: 2.8.0
# Summary: State-of-the-art Natural Language Processing for TensorFlow 2.0 and PyTorch
# Home-page: https://github.com/huggingface/transformers
# Author: Thomas Wolf, Lysandre Debut, Victor Sanh, Julien Chaumond, Sam Shleifer, Google AI Language Team Authors, Open AI team Authors, Facebook AI Authors, Carnegie Mellon University Authors
# Author-email: thomas@huggingface.co
# License: Apache
# Location: /opt/conda/lib/python3.6/site-packages
# Requires: sentencepiece, requests, tokenizers, sacremoses, tqdm, numpy, regex, boto3, dataclasses, filelock
# Required-by:

# %%
import os
import pickle
import json

import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow.keras.layers as L
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, average_precision_score, roc_auc_score, f1_score, accuracy_score
import matplotlib.pyplot as plt
import transformers as trfm
from transformers import AutoTokenizer, TFAutoModel, TFElectraModel, ElectraTokenizer
from tqdm.notebook import tqdm
from tokenizers import BertWordPieceTokenizer

# %% [markdown]
# ## Helper functions

# %%
def build_reranker(tokenizer, model):
    tokenizer.enable_padding()
    
    def rerank(question, answers):
        pairs = list(zip([question] * len(answers), answers))

        encs = tokenizer.encode_batch(pairs)
        input_ids = np.array([enc.ids for enc in encs])
        scores = model.predict(input_ids).squeeze()

        return scores
    
    return rerank

# %%
def touch_dir(dirname):
    if not os.path.exists(dirname):
        os.makedirs(dirname)
        print(f"Created directory {dirname}.")
    else:
        print(f"Directory {dirname} already exists.")

# %%
def fast_encode(texts, tokenizer, chunk_size=256, maxlen=512, enable_padding=False):
    """
    https://www.kaggle.com/xhlulu/jigsaw-tpu-distilbert-with-huggingface-and-keras
    
    ---
    Inputs:
        tokenizer: the `fast_tokenizer` that we imported from the tokenizers library
    """
    tokenizer.enable_truncation(max_length=maxlen)
    if enable_padding:
        tokenizer.enable_padding(max_length=maxlen)
    
    all_ids = []
    
    for i in tqdm(range(0, len(texts), chunk_size)):
        text_chunk = texts[i:i+chunk_size].tolist()
        encs = tokenizer.encode_batch(text_chunk)
        all_ids.extend([enc.ids for enc in encs])
    
    return np.array(all_ids)

# %%
def combine_qa_ids(q_ids, a_ids, tokenizer, maxlen=512):
    """
    Given two arrays of IDs (questions and answers) created by
    `fast_encode`, we combine and pad them.
    Inputs:
        tokenizer: The original tokenizer (not the fast_tokenizer)
    """
    combined_ids = []

    for i in tqdm(range(q_ids.shape[0])):
        ids = []
        ids.append(tokenizer.cls_token_id)
        ids.extend(q_ids[i])
        ids.append(tokenizer.sep_token_id)
        ids.extend(a_ids[i])
        ids.append(tokenizer.sep_token_id)
        ids.extend([tokenizer.pad_token_id] * (maxlen - len(ids)))

        combined_ids.append(ids)
    
    return np.array(combined_ids)

# %%
def encode_qa(questions, answers, tokenizer, maxlen=512):
    """
    https://www.kaggle.com/xhlulu/jigsaw-tpu-distilbert-with-huggingface-and-keras
    """
    tokenizer.enable_truncation(max_length=maxlen)
    tokenizer.enable_padding(max_length=maxlen)
    all_ids = []
    
    for i in tqdm(range(0, len(questions))):
        q = questions[i]
        a = answers[i]
        
        encs = tokenizer.encode(q, a)
        all_ids.append(encs.ids)
        if len(encs.ids) > 512:
            return q, a
    
    return np.array(all_ids)

# %%
def build_model(transformer, max_len=None):
    """
    https://www.kaggle.com/xhlulu/jigsaw-tpu-distilbert-with-huggingface-and-keras
    """
    input_ids = L.Input(shape=(max_len, ), dtype=tf.int32)
    
    x = transformer(input_ids)[0]
    x = x[:, 0, :]
    x = L.Dense(1, activation='sigmoid', name='sigmoid')(x)
    
    # BUILD AND COMPILE MODEL
    model = Model(inputs=input_ids, outputs=x)
    model.compile(
        loss='binary_crossentropy', 
        metrics=['accuracy'], 
        optimizer=Adam(lr=1e-5)
    )
    
    return model

# %%
def load_model(sigmoid_dir, transformer_dir='transformer', architecture="electra", max_len=None):
    """
    Special function to load a keras model that uses a transformer layer
    """
    sigmoid_path = os.path.join(sigmoid_dir,'sigmoid.pickle')
    
    if architecture == 'electra':
        transformer = TFElectraModel.from_pretrained(transformer_dir)
    else:
        transformer = TFAutoModel.from_pretrained(transformer_dir)
    model = build_model(transformer, max_len=max_len)
    
    sigmoid = pickle.load(open(sigmoid_path, 'rb'))
    model.get_layer('sigmoid').set_weights(sigmoid)
    
    return model

# %%
tokenizer = trfm.ElectraTokenizer.from_pretrained("google/electra-small-discriminator")
fast_tokenizer = BertWordPieceTokenizer('/kaggle/input/healthtap-joint-electra-small/vocab.txt', lowercase=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…

# %% [markdown]
# ## Load Models

# %%
models = {}

# %%
models['electra_ht_small'] = load_model(
    sigmoid_dir='/kaggle/input/healthtap-joint-electra-small',
    transformer_dir='/kaggle/input/healthtap-joint-electra-small/transformer',
    architecture='electra',
    max_len=None
)

models['electra_ht_small'].summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None)]            0
# _________________________________________________________________
# tf_electra_model (TFElectraM ((None, None, 256),)      13483008
# _________________________________________________________________
# tf_op_layer_strided_slice (T [(None, 256)]             0
# _________________________________________________________________
# sigmoid (Dense)              (None, 1)                 257
# =================================================================
# Total params: 13,483,265
# Trainable params: 13,483,265
# Non-trainable params: 0
# _________________________________________________________________

# %%
models['electra_ht_base'] = load_model(
    sigmoid_dir='/kaggle/input/healthtap-joint-electra-base',
    transformer_dir='/kaggle/input/healthtap-joint-electra-base/transformer',
    architecture='electra',
    max_len=None
)

models['electra_ht_base'].summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, None)]            0
# _________________________________________________________________
# tf_electra_model_1 (TFElectr ((None, None, 768),)      108891648
# _________________________________________________________________
# tf_op_layer_strided_slice_1  [(None, 768)]             0
# _________________________________________________________________
# sigmoid (Dense)              (None, 1)                 769
# =================================================================
# Total params: 108,892,417
# Trainable params: 108,892,417
# Non-trainable params: 0
# _________________________________________________________________

# %%
models['electra_se_small'] = load_model(
    sigmoid_dir='/kaggle/input/stackexchange-finetune-electra-small/transformer',
    transformer_dir='/kaggle/input/stackexchange-finetune-electra-small/transformer',
    architecture='electra',
    max_len=None
)

models['electra_se_small'].summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, None)]            0
# _________________________________________________________________
# tf_electra_model_2 (TFElectr ((None, None, 256),)      13483008
# _________________________________________________________________
# tf_op_layer_strided_slice_2  [(None, 256)]             0
# _________________________________________________________________
# sigmoid (Dense)              (None, 1)                 257
# =================================================================
# Total params: 13,483,265
# Trainable params: 13,483,265
# Non-trainable params: 0
# _________________________________________________________________

# %%
models['electra_se_base'] = load_model(
    sigmoid_dir='/kaggle/input/stackexchange-finetune-electra-base/transformer',
    transformer_dir='/kaggle/input/stackexchange-finetune-electra-base/transformer',
    architecture='electra',
    max_len=None
)

models['electra_se_base'].summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, None)]            0
# _________________________________________________________________
# tf_electra_model_3 (TFElectr ((None, None, 768),)      108891648
# _________________________________________________________________
# tf_op_layer_strided_slice_3  [(None, 768)]             0
# _________________________________________________________________
# sigmoid (Dense)              (None, 1)                 769
# =================================================================
# Total params: 108,892,417
# Trainable params: 108,892,417
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Load Data

# %%
MAX_LEN = 512

df = pd.read_csv('/kaggle/input/covidqa/news.csv')

# %%
correct_ids = encode_qa(df.question.values.astype(str), df.answer.values.astype(str), fast_tokenizer, maxlen=MAX_LEN)
wrong_ids = encode_qa(df.question.values.astype(str), df.wrong_answer.values.astype(str), fast_tokenizer, maxlen=MAX_LEN)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=481.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=481.0), HTML(value='')))

# %%
input_ids = np.concatenate([correct_ids, wrong_ids])

labels = np.concatenate([
    np.ones(correct_ids.shape[0]),
    np.zeros(correct_ids.shape[0])
]).astype(np.int32)

# %% [markdown]
# ## Compute Scores

# %%
score_df = pd.concat([df[['source']]]*2)

for model_name, model in models.items():
    # %time score_df[model_name] = model.predict(input_ids, batch_size=64)
# Out:
# CPU times: user 3.95 s, sys: 275 ms, total: 4.23 s
# Wall time: 7.55 s
# CPU times: user 5.36 s, sys: 1.09 s, total: 6.46 s
# Wall time: 22.4 s
# CPU times: user 4.15 s, sys: 234 ms, total: 4.39 s
# Wall time: 7.64 s
# CPU times: user 5.47 s, sys: 1.05 s, total: 6.52 s
# Wall time: 22.4 s

# %%
score_df['labels'] = labels

# %%
score_df.to_csv('news.csv', index=False)

# %% [markdown]
# ## Compute Prediction Results

# %% [markdown]
# ### Macro-Average

# %%
overall = {}

for model_name in models.keys():
    result = {}
    labels = score_df['labels']
    score = score_df[model_name]
    pred = score.round().astype(int)
    result['ap'] = average_precision_score(labels, score).round(4)
    result['roc_auc'] = roc_auc_score(labels, score).round(4)
    result['f1_score'] = f1_score(labels, pred).round(4)
    result['accuracy'] = accuracy_score(labels, pred).round(4)
    overall[model_name] = result

overall_df = pd.DataFrame(overall)
overall_df.to_csv("overall_results.csv")
overall_df
# Out:
#           electra_ht_small  electra_ht_base  electra_se_small  electra_se_base
# ap                  0.9038           0.9273            0.6691           0.7553
# roc_auc             0.9186           0.9327            0.7164           0.8053
# f1_score            0.8433           0.8527            0.7113           0.7762
# accuracy            0.8420           0.8524            0.6590           0.7266

# %%
print(overall_df.to_latex())
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# {} &  electra\_ht\_small &  electra\_ht\_base &  electra\_se\_small &  electra\_se\_base \\
# \midrule
# ap       &            0.9038 &           0.9273 &            0.6691 &           0.7553 \\
# roc\_auc  &            0.9186 &           0.9327 &            0.7164 &           0.8053 \\
# f1\_score &            0.8433 &           0.8527 &            0.7113 &           0.7762 \\
# accuracy &            0.8420 &           0.8524 &            0.6590 &           0.7266 \\
# \bottomrule
# \end{tabular}

# %%
print(overall_df.to_markdown())
# Out:
# |          |   electra_ht_small |   electra_ht_base |   electra_se_small |   electra_se_base |
# |:---------|-------------------:|------------------:|-------------------:|------------------:|
# | ap       |             0.9038 |            0.9273 |             0.6691 |            0.7553 |
# | roc_auc  |             0.9186 |            0.9327 |             0.7164 |            0.8053 |
# | f1_score |             0.8433 |            0.8527 |             0.7113 |            0.7762 |
# | accuracy |             0.842  |            0.8524 |             0.659  |            0.7266 |

# %% [markdown]
# ## By source

# %%
all_sources = {}

for source in df.source.unique():
    source_results = {}
    score_source_df = score_df[score_df.source == source]

    for model_name in models.keys():
        result = {}
        labels = score_source_df['labels']
        score = score_source_df[model_name]
        pred = score.round().astype(int)
        result['ap'] = average_precision_score(labels, score).round(4)
        result['roc_auc'] = roc_auc_score(labels, score).round(4)
        result['f1_score'] = f1_score(labels, pred).round(4)
        result['accuracy'] = accuracy_score(labels, pred).round(4)
        
        source_results[model_name] = result
    
    all_sources[source] = pd.DataFrame(source_results)

# %% [markdown]
# ### Regular output

# %%
for source, sdf in all_sources.items():
    print(source)
    print('-'*40)
    print(sdf)
    print('='*40)
# Out:
# ABC Australia
# ----------------------------------------
#           electra_ht_small  electra_ht_base  electra_se_small  electra_se_base
# ap                  0.8968           0.8860            0.6931           0.7400
# roc_auc             0.9062           0.8867            0.6914           0.7422
# f1_score            0.8125           0.7333            0.7059           0.7442
# accuracy            0.8125           0.7500            0.6875           0.6562
# ========================================
# ABC News
# ----------------------------------------
#           electra_ht_small  electra_ht_base  electra_se_small  electra_se_base
# ap                  0.8825           0.9334            0.6492           0.6274
# roc_auc             0.9259           0.9344            0.5995           0.6258
# f1_score            0.8800           0.8649            0.6207           0.7200
# accuracy            0.8750           0.8611            0.5417           0.6111
# ========================================
# BBC
# ----------------------------------------
#           electra_ht_small  electra_ht_base  electra_se_small  electra_se_base
# ap                  0.8977           0.9259            0.7382           0.8679
# roc_auc             0.9172           0.9172            0.7825           0.8772
# f1_score            0.8462           0.8462            0.7385           0.8070
# accuracy            0.8462           0.8462            0.6731           0.7885
# ========================================
# CNN
# ----------------------------------------
#           electra_ht_small  electra_ht_base  electra_se_small  electra_se_base
# ap                  0.9525           0.9436            0.7052           0.8598
# roc_auc             0.9487           0.9432            0.7231           0.8640
# f1_score            0.8519           0.8519            0.6720           0.8062
# accuracy            0.8519           0.8519            0.6204           0.7685
# ========================================
# CTV
# ----------------------------------------
#           electra_ht_small  electra_ht_base  electra_se_small  electra_se_base
# ap                  0.8225           0.9339            0.7062           0.8579
# roc_auc             0.8673           0.9337            0.7347           0.8520
# f1_score            0.8276           0.8148            0.7647           0.7647
# accuracy            0.8214           0.8214            0.7143           0.7143
# ========================================
# Forbes
# ----------------------------------------
#           electra_ht_small  electra_ht_base  electra_se_small  electra_se_base
# ap                  0.7534           0.8302            0.7077           0.7361
# roc_auc             0.8536           0.8772            0.6642           0.7219
# f1_score            0.7600           0.7843            0.6897           0.7385
# accuracy            0.7692           0.7885            0.6538           0.6731
# ========================================
# LA Times
# ----------------------------------------
#           electra_ht_small  electra_ht_base  electra_se_small  electra_se_base
# ap                  0.8750           0.9500            0.7095           0.6458
# roc_auc             0.7500           0.9375            0.6250           0.6875
# f1_score            0.8571           0.8571            0.6667           0.6667
# accuracy            0.8750           0.8750            0.6250           0.5000
# ========================================
# NDTV
# ----------------------------------------
#           electra_ht_small  electra_ht_base  electra_se_small  electra_se_base
# ap                  0.8675           0.8915            0.6790           0.7449
# roc_auc             0.8752           0.8832            0.6448           0.7536
# f1_score            0.7869           0.7797            0.6885           0.7164
# accuracy            0.7400           0.7400            0.6200           0.6200
# ========================================
# NPR
# ----------------------------------------
#           electra_ht_small  electra_ht_base  electra_se_small  electra_se_base
# ap                  0.9720           0.9637            0.6752           0.8085
# roc_auc             0.9700           0.9600            0.7350           0.8400
# f1_score            0.8421           0.8718            0.7826           0.8333
# accuracy            0.8500           0.8750            0.7500           0.8000
# ========================================
# NY Times
# ----------------------------------------
#           electra_ht_small  electra_ht_base  electra_se_small  electra_se_base
# ap                  0.9604           0.9455            0.6489           0.8077
# roc_auc             0.9560           0.9462            0.7191           0.8498
# f1_score            0.8519           0.8571            0.7315           0.8230
# accuracy            0.8667           0.8667            0.6778           0.7944
# ========================================
# SCMP
# ----------------------------------------
#           electra_ht_small  electra_ht_base  electra_se_small  electra_se_base
# ap                  0.9415           0.9464            0.8155           0.8523
# roc_auc             0.9375           0.9062            0.7969           0.8750
# f1_score            0.7143           0.8571            0.6667           0.8889
# accuracy            0.7500           0.8750            0.6875           0.8750
# ========================================
# The Australian
# ----------------------------------------
#           electra_ht_small  electra_ht_base  electra_se_small  electra_se_base
# ap                  0.8179           0.8000            0.6070           0.8556
# roc_auc             0.8611           0.8333            0.5278           0.8611
# f1_score            0.6000           0.7273            0.6667           0.7500
# accuracy            0.6667           0.7500            0.5833           0.6667
# ========================================
# The Hill
# ----------------------------------------
#           electra_ht_small  electra_ht_base  electra_se_small  electra_se_base
# ap                  0.9377           0.9734            0.6382           0.7539
# roc_auc             0.9340           0.9705            0.6684           0.8142
# f1_score            0.8400           0.8800            0.7458           0.8000
# accuracy            0.8333           0.8750            0.6875           0.7708
# ========================================
# Times Of India
# ----------------------------------------
#           electra_ht_small  electra_ht_base  electra_se_small  electra_se_base
# ap                  0.9869           0.9824            0.7823           0.7366
# roc_auc             0.9860           0.9826            0.8129           0.8017
# f1_score            0.9041           0.9231            0.7467           0.7500
# accuracy            0.8955           0.9179            0.7164           0.7015
# ========================================
# USA Today
# ----------------------------------------
#           electra_ht_small  electra_ht_base  electra_se_small  electra_se_base
# ap                  0.8995           0.9391            0.7237           0.7689
# roc_auc             0.9019           0.9364            0.7440           0.8252
# f1_score            0.8382           0.8550            0.7037           0.7654
# accuracy            0.8308           0.8538            0.6308           0.7077
# ========================================

# %% [markdown]
# ### Latex output

# %%
for source, sdf in all_sources.items():
    print(source)
    print('-'*40)
    print(sdf.to_latex())
    print('='*40)
# Out:
# ABC Australia
# ----------------------------------------
# \begin{tabular}{lrrrr}
# \toprule
# {} &  electra\_ht\_small &  electra\_ht\_base &  electra\_se\_small &  electra\_se\_base \\
# \midrule
# ap       &            0.8968 &           0.8860 &            0.6931 &           0.7400 \\
# roc\_auc  &            0.9062 &           0.8867 &            0.6914 &           0.7422 \\
# f1\_score &            0.8125 &           0.7333 &            0.7059 &           0.7442 \\
# accuracy &            0.8125 &           0.7500 &            0.6875 &           0.6562 \\
# \bottomrule
# \end{tabular}
#
# ========================================
# ABC News
# ----------------------------------------
# \begin{tabular}{lrrrr}
# \toprule
# {} &  electra\_ht\_small &  electra\_ht\_base &  electra\_se\_small &  electra\_se\_base \\
# \midrule
# ap       &            0.8825 &           0.9334 &            0.6492 &           0.6274 \\
# roc\_auc  &            0.9259 &           0.9344 &            0.5995 &           0.6258 \\
# f1\_score &            0.8800 &           0.8649 &            0.6207 &           0.7200 \\
# accuracy &            0.8750 &           0.8611 &            0.5417 &           0.6111 \\
# \bottomrule
# \end{tabular}
#
# ========================================
# BBC
# ----------------------------------------
# \begin{tabular}{lrrrr}
# \toprule
# {} &  electra\_ht\_small &  electra\_ht\_base &  electra\_se\_small &  electra\_se\_base \\
# \midrule
# ap       &            0.8977 &           0.9259 &            0.7382 &           0.8679 \\
# roc\_auc  &            0.9172 &           0.9172 &            0.7825 &           0.8772 \\
# f1\_score &            0.8462 &           0.8462 &            0.7385 &           0.8070 \\
# accuracy &            0.8462 &           0.8462 &            0.6731 &           0.7885 \\
# \bottomrule
# \end{tabular}
#
# ========================================
# CNN
# ----------------------------------------
# \begin{tabular}{lrrrr}
# \toprule
# {} &  electra\_ht\_small &  electra\_ht\_base &  electra\_se\_small &  electra\_se\_base \\
# \midrule
# ap       &            0.9525 &           0.9436 &            0.7052 &           0.8598 \\
# roc\_auc  &            0.9487 &           0.9432 &            0.7231 &           0.8640 \\
# f1\_score &            0.8519 &           0.8519 &            0.6720 &           0.8062 \\
# accuracy &            0.8519 &           0.8519 &            0.6204 &           0.7685 \\
# \bottomrule
# \end{tabular}
#
# ========================================
# CTV
# ----------------------------------------
# \begin{tabular}{lrrrr}
# \toprule
# {} &  electra\_ht\_small &  electra\_ht\_base &  electra\_se\_small &  electra\_se\_base \\
# \midrule
# ap       &            0.8225 &           0.9339 &            0.7062 &           0.8579 \\
# roc\_auc  &            0.8673 &           0.9337 &            0.7347 &           0.8520 \\
# f1\_score &            0.8276 &           0.8148 &            0.7647 &           0.7647 \\
# accuracy &            0.8214 &           0.8214 &            0.7143 &           0.7143 \\
# \bottomrule
# \end{tabular}
#
# ========================================
# Forbes
# ----------------------------------------
# \begin{tabular}{lrrrr}
# \toprule
# {} &  electra\_ht\_small &  electra\_ht\_base &  electra\_se\_small &  electra\_se\_base \\
# \midrule
# ap       &            0.7534 &           0.8302 &            0.7077 &           0.7361 \\
# roc\_auc  &            0.8536 &           0.8772 &            0.6642 &           0.7219 \\
# f1\_score &            0.7600 &           0.7843 &            0.6897 &           0.7385 \\
# accuracy &            0.7692 &           0.7885 &            0.6538 &           0.6731 \\
# \bottomrule
# \end{tabular}
#
# ========================================
# LA Times
# ----------------------------------------
# \begin{tabular}{lrrrr}
# \toprule
# {} &  electra\_ht\_small &  electra\_ht\_base &  electra\_se\_small &  electra\_se\_base \\
# \midrule
# ap       &            0.8750 &           0.9500 &            0.7095 &           0.6458 \\
# roc\_auc  &            0.7500 &           0.9375 &            0.6250 &           0.6875 \\
# f1\_score &            0.8571 &           0.8571 &            0.6667 &           0.6667 \\
# accuracy &            0.8750 &           0.8750 &            0.6250 &           0.5000 \\
# \bottomrule
# \end{tabular}
#
# ========================================
# NDTV
# ----------------------------------------
# \begin{tabular}{lrrrr}
# \toprule
# {} &  electra\_ht\_small &  electra\_ht\_base &  electra\_se\_small &  electra\_se\_base \\
# \midrule
# ap       &            0.8675 &           0.8915 &            0.6790 &           0.7449 \\
# roc\_auc  &            0.8752 &           0.8832 &            0.6448 &           0.7536 \\
# f1\_score &            0.7869 &           0.7797 &            0.6885 &           0.7164 \\
# accuracy &            0.7400 &           0.7400 &            0.6200 &           0.6200 \\
# \bottomrule
# \end{tabular}
#
# ========================================
# NPR
# ----------------------------------------
# \begin{tabular}{lrrrr}
# \toprule
# {} &  electra\_ht\_small &  electra\_ht\_base &  electra\_se\_small &  electra\_se\_base \\
# \midrule
# ap       &            0.9720 &           0.9637 &            0.6752 &           0.8085 \\
# roc\_auc  &            0.9700 &           0.9600 &            0.7350 &           0.8400 \\
# f1\_score &            0.8421 &           0.8718 &            0.7826 &           0.8333 \\
# accuracy &            0.8500 &           0.8750 &            0.7500 &           0.8000 \\
# \bottomrule
# \end{tabular}
#
# ========================================
# NY Times
# ----------------------------------------
# \begin{tabular}{lrrrr}
# \toprule
# {} &  electra\_ht\_small &  electra\_ht\_base &  electra\_se\_small &  electra\_se\_base \\
# \midrule
# ap       &            0.9604 &           0.9455 &            0.6489 &           0.8077 \\
# roc\_auc  &            0.9560 &           0.9462 &            0.7191 &           0.8498 \\
# f1\_score &            0.8519 &           0.8571 &            0.7315 &           0.8230 \\
# accuracy &            0.8667 &           0.8667 &            0.6778 &           0.7944 \\
# \bottomrule
# \end{tabular}
#
# ========================================
# SCMP
# ----------------------------------------
# \begin{tabular}{lrrrr}
# \toprule
# {} &  electra\_ht\_small &  electra\_ht\_base &  electra\_se\_small &  electra\_se\_base \\
# \midrule
# ap       &            0.9415 &           0.9464 &            0.8155 &           0.8523 \\
# roc\_auc  &            0.9375 &           0.9062 &            0.7969 &           0.8750 \\
# f1\_score &            0.7143 &           0.8571 &            0.6667 &           0.8889 \\
# accuracy &            0.7500 &           0.8750 &            0.6875 &           0.8750 \\
# \bottomrule
# \end{tabular}
#
# ========================================
# The Australian
# ----------------------------------------
# \begin{tabular}{lrrrr}
# \toprule
# {} &  electra\_ht\_small &  electra\_ht\_base &  electra\_se\_small &  electra\_se\_base \\
# \midrule
# ap       &            0.8179 &           0.8000 &            0.6070 &           0.8556 \\
# roc\_auc  &            0.8611 &           0.8333 &            0.5278 &           0.8611 \\
# f1\_score &            0.6000 &           0.7273 &            0.6667 &           0.7500 \\
# accuracy &            0.6667 &           0.7500 &            0.5833 &           0.6667 \\
# \bottomrule
# \end{tabular}
#
# ========================================
# The Hill
# ----------------------------------------
# \begin{tabular}{lrrrr}
# \toprule
# {} &  electra\_ht\_small &  electra\_ht\_base &  electra\_se\_small &  electra\_se\_base \\
# \midrule
# ap       &            0.9377 &           0.9734 &            0.6382 &           0.7539 \\
# roc\_auc  &            0.9340 &           0.9705 &            0.6684 &           0.8142 \\
# f1\_score &            0.8400 &           0.8800 &            0.7458 &           0.8000 \\
# accuracy &            0.8333 &           0.8750 &            0.6875 &           0.7708 \\
# \bottomrule
# \end{tabular}
#
# ========================================
# Times Of India
# ----------------------------------------
# \begin{tabular}{lrrrr}
# \toprule
# {} &  electra\_ht\_small &  electra\_ht\_base &  electra\_se\_small &  electra\_se\_base \\
# \midrule
# ap       &            0.9869 &           0.9824 &            0.7823 &           0.7366 \\
# roc\_auc  &            0.9860 &           0.9826 &            0.8129 &           0.8017 \\
# f1\_score &            0.9041 &           0.9231 &            0.7467 &           0.7500 \\
# accuracy &            0.8955 &           0.9179 &            0.7164 &           0.7015 \\
# \bottomrule
# \end{tabular}
#
# ========================================
# USA Today
# ----------------------------------------
# \begin{tabular}{lrrrr}
# \toprule
# {} &  electra\_ht\_small &  electra\_ht\_base &  electra\_se\_small &  electra\_se\_base \\
# \midrule
# ap       &            0.8995 &           0.9391 &            0.7237 &           0.7689 \\
# roc\_auc  &            0.9019 &           0.9364 &            0.7440 &           0.8252 \\
# f1\_score &            0.8382 &           0.8550 &            0.7037 &           0.7654 \\
# accuracy &            0.8308 &           0.8538 &            0.6308 &           0.7077 \\
# \bottomrule
# \end{tabular}
#
# ========================================

# %% [markdown]
# ### Markdown output

# %%
for source, sdf in all_sources.items():
    print(source)
    print('-'*40)
    print(sdf.to_markdown())
    print('='*40)
# Out:
# ABC Australia
# ----------------------------------------
# |          |   electra_ht_small |   electra_ht_base |   electra_se_small |   electra_se_base |
# |:---------|-------------------:|------------------:|-------------------:|------------------:|
# | ap       |             0.8968 |            0.886  |             0.6931 |            0.74   |
# | roc_auc  |             0.9062 |            0.8867 |             0.6914 |            0.7422 |
# | f1_score |             0.8125 |            0.7333 |             0.7059 |            0.7442 |
# | accuracy |             0.8125 |            0.75   |             0.6875 |            0.6562 |
# ========================================
# ABC News
# ----------------------------------------
# |          |   electra_ht_small |   electra_ht_base |   electra_se_small |   electra_se_base |
# |:---------|-------------------:|------------------:|-------------------:|------------------:|
# | ap       |             0.8825 |            0.9334 |             0.6492 |            0.6274 |
# | roc_auc  |             0.9259 |            0.9344 |             0.5995 |            0.6258 |
# | f1_score |             0.88   |            0.8649 |             0.6207 |            0.72   |
# | accuracy |             0.875  |            0.8611 |             0.5417 |            0.6111 |
# ========================================
# BBC
# ----------------------------------------
# |          |   electra_ht_small |   electra_ht_base |   electra_se_small |   electra_se_base |
# |:---------|-------------------:|------------------:|-------------------:|------------------:|
# | ap       |             0.8977 |            0.9259 |             0.7382 |            0.8679 |
# | roc_auc  |             0.9172 |            0.9172 |             0.7825 |            0.8772 |
# | f1_score |             0.8462 |            0.8462 |             0.7385 |            0.807  |
# | accuracy |             0.8462 |            0.8462 |             0.6731 |            0.7885 |
# ========================================
# CNN
# ----------------------------------------
# |          |   electra_ht_small |   electra_ht_base |   electra_se_small |   electra_se_base |
# |:---------|-------------------:|------------------:|-------------------:|------------------:|
# | ap       |             0.9525 |            0.9436 |             0.7052 |            0.8598 |
# | roc_auc  |             0.9487 |            0.9432 |             0.7231 |            0.864  |
# | f1_score |             0.8519 |            0.8519 |             0.672  |            0.8062 |
# | accuracy |             0.8519 |            0.8519 |             0.6204 |            0.7685 |
# ========================================
# CTV
# ----------------------------------------
# |          |   electra_ht_small |   electra_ht_base |   electra_se_small |   electra_se_base |
# |:---------|-------------------:|------------------:|-------------------:|------------------:|
# | ap       |             0.8225 |            0.9339 |             0.7062 |            0.8579 |
# | roc_auc  |             0.8673 |            0.9337 |             0.7347 |            0.852  |
# | f1_score |             0.8276 |            0.8148 |             0.7647 |            0.7647 |
# | accuracy |             0.8214 |            0.8214 |             0.7143 |            0.7143 |
# ========================================
# Forbes
# ----------------------------------------
# |          |   electra_ht_small |   electra_ht_base |   electra_se_small |   electra_se_base |
# |:---------|-------------------:|------------------:|-------------------:|------------------:|
# | ap       |             0.7534 |            0.8302 |             0.7077 |            0.7361 |
# | roc_auc  |             0.8536 |            0.8772 |             0.6642 |            0.7219 |
# | f1_score |             0.76   |            0.7843 |             0.6897 |            0.7385 |
# | accuracy |             0.7692 |            0.7885 |             0.6538 |            0.6731 |
# ========================================
# LA Times
# ----------------------------------------
# |          |   electra_ht_small |   electra_ht_base |   electra_se_small |   electra_se_base |
# |:---------|-------------------:|------------------:|-------------------:|------------------:|
# | ap       |             0.875  |            0.95   |             0.7095 |            0.6458 |
# | roc_auc  |             0.75   |            0.9375 |             0.625  |            0.6875 |
# | f1_score |             0.8571 |            0.8571 |             0.6667 |            0.6667 |
# | accuracy |             0.875  |            0.875  |             0.625  |            0.5    |
# ========================================
# NDTV
# ----------------------------------------
# |          |   electra_ht_small |   electra_ht_base |   electra_se_small |   electra_se_base |
# |:---------|-------------------:|------------------:|-------------------:|------------------:|
# | ap       |             0.8675 |            0.8915 |             0.679  |            0.7449 |
# | roc_auc  |             0.8752 |            0.8832 |             0.6448 |            0.7536 |
# | f1_score |             0.7869 |            0.7797 |             0.6885 |            0.7164 |
# | accuracy |             0.74   |            0.74   |             0.62   |            0.62   |
# ========================================
# NPR
# ----------------------------------------
# |          |   electra_ht_small |   electra_ht_base |   electra_se_small |   electra_se_base |
# |:---------|-------------------:|------------------:|-------------------:|------------------:|
# | ap       |             0.972  |            0.9637 |             0.6752 |            0.8085 |
# | roc_auc  |             0.97   |            0.96   |             0.735  |            0.84   |
# | f1_score |             0.8421 |            0.8718 |             0.7826 |            0.8333 |
# | accuracy |             0.85   |            0.875  |             0.75   |            0.8    |
# ========================================
# NY Times
# ----------------------------------------
# |          |   electra_ht_small |   electra_ht_base |   electra_se_small |   electra_se_base |
# |:---------|-------------------:|------------------:|-------------------:|------------------:|
# | ap       |             0.9604 |            0.9455 |             0.6489 |            0.8077 |
# | roc_auc  |             0.956  |            0.9462 |             0.7191 |            0.8498 |
# | f1_score |             0.8519 |            0.8571 |             0.7315 |            0.823  |
# | accuracy |             0.8667 |            0.8667 |             0.6778 |            0.7944 |
# ========================================
# SCMP
# ----------------------------------------
# |          |   electra_ht_small |   electra_ht_base |   electra_se_small |   electra_se_base |
# |:---------|-------------------:|------------------:|-------------------:|------------------:|
# | ap       |             0.9415 |            0.9464 |             0.8155 |            0.8523 |
# | roc_auc  |             0.9375 |            0.9062 |             0.7969 |            0.875  |
# | f1_score |             0.7143 |            0.8571 |             0.6667 |            0.8889 |
# | accuracy |             0.75   |            0.875  |             0.6875 |            0.875  |
# ========================================
# The Australian
# ----------------------------------------
# |          |   electra_ht_small |   electra_ht_base |   electra_se_small |   electra_se_base |
# |:---------|-------------------:|------------------:|-------------------:|------------------:|
# | ap       |             0.8179 |            0.8    |             0.607  |            0.8556 |
# | roc_auc  |             0.8611 |            0.8333 |             0.5278 |            0.8611 |
# | f1_score |             0.6    |            0.7273 |             0.6667 |            0.75   |
# | accuracy |             0.6667 |            0.75   |             0.5833 |            0.6667 |
# ========================================
# The Hill
# ----------------------------------------
# |          |   electra_ht_small |   electra_ht_base |   electra_se_small |   electra_se_base |
# |:---------|-------------------:|------------------:|-------------------:|------------------:|
# | ap       |             0.9377 |            0.9734 |             0.6382 |            0.7539 |
# | roc_auc  |             0.934  |            0.9705 |             0.6684 |            0.8142 |
# | f1_score |             0.84   |            0.88   |             0.7458 |            0.8    |
# | accuracy |             0.8333 |            0.875  |             0.6875 |            0.7708 |
# ========================================
# Times Of India
# ----------------------------------------
# |          |   electra_ht_small |   electra_ht_base |   electra_se_small |   electra_se_base |
# |:---------|-------------------:|------------------:|-------------------:|------------------:|
# | ap       |             0.9869 |            0.9824 |             0.7823 |            0.7366 |
# | roc_auc  |             0.986  |            0.9826 |             0.8129 |            0.8017 |
# | f1_score |             0.9041 |            0.9231 |             0.7467 |            0.75   |
# | accuracy |             0.8955 |            0.9179 |             0.7164 |            0.7015 |
# ========================================
# USA Today
# ----------------------------------------
# |          |   electra_ht_small |   electra_ht_base |   electra_se_small |   electra_se_base |
# |:---------|-------------------:|------------------:|-------------------:|------------------:|
# | ap       |             0.8995 |            0.9391 |             0.7237 |            0.7689 |
# | roc_auc  |             0.9019 |            0.9364 |             0.744  |            0.8252 |
# | f1_score |             0.8382 |            0.855  |             0.7037 |            0.7654 |
# | accuracy |             0.8308 |            0.8538 |             0.6308 |            0.7077 |
# ========================================

# %% [markdown]
# ## AP Score by source

# %%
ap_df = pd.DataFrame({source: sdf.loc['ap'] for source, sdf in all_sources.items()}).T
ap_df
# Out:
#                 electra_ht_small  electra_ht_base  electra_se_small  \
# ABC Australia             0.8968           0.8860            0.6931
# ABC News                  0.8825           0.9334            0.6492
# BBC                       0.8977           0.9259            0.7382
# CNN                       0.9525           0.9436            0.7052
# CTV                       0.8225           0.9339            0.7062
# Forbes                    0.7534           0.8302            0.7077
# LA Times                  0.8750           0.9500            0.7095
# NDTV                      0.8675           0.8915            0.6790
# NPR                       0.9720           0.9637            0.6752
# NY Times                  0.9604           0.9455            0.6489
# SCMP                      0.9415           0.9464            0.8155
# The Australian            0.8179           0.8000            0.6070
# The Hill                  0.9377           0.9734            0.6382
# Times Of India            0.9869           0.9824            0.7823
# USA Today                 0.8995           0.9391            0.7237
#
#                 electra_se_base
# ABC Australia            0.7400
# ABC News                 0.6274
# BBC                      0.8679
# CNN                      0.8598
# CTV                      0.8579
# Forbes                   0.7361
# LA Times                 0.6458
# NDTV                     0.7449
# NPR                      0.8085
# NY Times                 0.8077
# SCMP                     0.8523
# The Australian           0.8556
# The Hill                 0.7539
# Times Of India           0.7366
# USA Today                0.7689

# %%
print(ap_df.to_latex())
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# {} &  electra\_ht\_small &  electra\_ht\_base &  electra\_se\_small &  electra\_se\_base \\
# \midrule
# ABC Australia  &            0.8968 &           0.8860 &            0.6931 &           0.7400 \\
# ABC News       &            0.8825 &           0.9334 &            0.6492 &           0.6274 \\
# BBC            &            0.8977 &           0.9259 &            0.7382 &           0.8679 \\
# CNN            &            0.9525 &           0.9436 &            0.7052 &           0.8598 \\
# CTV            &            0.8225 &           0.9339 &            0.7062 &           0.8579 \\
# Forbes         &            0.7534 &           0.8302 &            0.7077 &           0.7361 \\
# LA Times       &            0.8750 &           0.9500 &            0.7095 &           0.6458 \\
# NDTV           &            0.8675 &           0.8915 &            0.6790 &           0.7449 \\
# NPR            &            0.9720 &           0.9637 &            0.6752 &           0.8085 \\
# NY Times       &            0.9604 &           0.9455 &            0.6489 &           0.8077 \\
# SCMP           &            0.9415 &           0.9464 &            0.8155 &           0.8523 \\
# The Australian &            0.8179 &           0.8000 &            0.6070 &           0.8556 \\
# The Hill       &            0.9377 &           0.9734 &            0.6382 &           0.7539 \\
# Times Of India &            0.9869 &           0.9824 &            0.7823 &           0.7366 \\
# USA Today      &            0.8995 &           0.9391 &            0.7237 &           0.7689 \\
# \bottomrule
# \end{tabular}

# %%
print(ap_df.to_markdown())
# Out:
# |                |   electra_ht_small |   electra_ht_base |   electra_se_small |   electra_se_base |
# |:---------------|-------------------:|------------------:|-------------------:|------------------:|
# | ABC Australia  |             0.8968 |            0.886  |             0.6931 |            0.74   |
# | ABC News       |             0.8825 |            0.9334 |             0.6492 |            0.6274 |
# | BBC            |             0.8977 |            0.9259 |             0.7382 |            0.8679 |
# | CNN            |             0.9525 |            0.9436 |             0.7052 |            0.8598 |
# | CTV            |             0.8225 |            0.9339 |             0.7062 |            0.8579 |
# | Forbes         |             0.7534 |            0.8302 |             0.7077 |            0.7361 |
# | LA Times       |             0.875  |            0.95   |             0.7095 |            0.6458 |
# | NDTV           |             0.8675 |            0.8915 |             0.679  |            0.7449 |
# | NPR            |             0.972  |            0.9637 |             0.6752 |            0.8085 |
# | NY Times       |             0.9604 |            0.9455 |             0.6489 |            0.8077 |
# | SCMP           |             0.9415 |            0.9464 |             0.8155 |            0.8523 |
# | The Australian |             0.8179 |            0.8    |             0.607  |            0.8556 |
# | The Hill       |             0.9377 |            0.9734 |             0.6382 |            0.7539 |
# | Times Of India |             0.9869 |            0.9824 |             0.7823 |            0.7366 |
# | USA Today      |             0.8995 |            0.9391 |             0.7237 |            0.7689 |

# %% [markdown]
# ## Micro Scores

# %%
micro_df = (sum(all_sources.values()) / len(all_sources)).round(4)
micro_df
# Out:
#           electra_ht_small  electra_ht_base  electra_se_small  electra_se_base
# ap                  0.8976           0.9230            0.6986           0.7776
# roc_auc             0.9060           0.9232            0.6980           0.7994
# f1_score            0.8142           0.8336            0.7060           0.7716
# accuracy            0.8189           0.8365            0.6579           0.7099

# %%
print(micro_df.to_latex())
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# {} &  electra\_ht\_small &  electra\_ht\_base &  electra\_se\_small &  electra\_se\_base \\
# \midrule
# ap       &            0.8976 &           0.9230 &            0.6986 &           0.7776 \\
# roc\_auc  &            0.9060 &           0.9232 &            0.6980 &           0.7994 \\
# f1\_score &            0.8142 &           0.8336 &            0.7060 &           0.7716 \\
# accuracy &            0.8189 &           0.8365 &            0.6579 &           0.7099 \\
# \bottomrule
# \end{tabular}

# %%
print(micro_df.to_markdown())
# Out:
# |          |   electra_ht_small |   electra_ht_base |   electra_se_small |   electra_se_base |
# |:---------|-------------------:|------------------:|-------------------:|------------------:|
# | ap       |             0.8976 |            0.923  |             0.6986 |            0.7776 |
# | roc_auc  |             0.906  |            0.9232 |             0.698  |            0.7994 |
# | f1_score |             0.8142 |            0.8336 |             0.706  |            0.7716 |
# | accuracy |             0.8189 |            0.8365 |             0.6579 |            0.7099 |
