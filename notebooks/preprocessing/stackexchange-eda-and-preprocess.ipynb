# %%
# !mkdir covid
# !mkdir pre_covid

# %%
import os
import re

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from tqdm.notebook import tqdm

# %%
tqdm.pandas()

# %% [markdown]
# # Helper Functions

# %%
TAG_RE = re.compile('<[^>]*>')

# Currently unused:
CODE_RE = re.compile(r'<code>((.|\n|\r)*)</code>')
SPACE_RE = re.compile(r"(\n|\r)")
TAB_RE = re.compile(r"\t")


def clean(text):
    text = re.sub(TAG_RE, '', text)    
    return text

# %%
def negative_sampling(positives, negatives, size=1, random_state=0):
    """
    if you are sampling negatives within the same array, simply run
    `negative_sampling(positives, positives)`.
    
    input:
        positives (np.array): We are iterating through this array
        negatives (np.array): The negative candidates from which we will sample
        size (int): number of negative samples for every positive
        random_state (int): seed for numpy's random
    returns:
        choices (np.array): All the sampled negatives (i.e. they don't
        have the same value as the currently sampled positive)
    """
    np.random.seed(random_state)
    choices = []

    for val in tqdm(positives, leave=False):
        rest = negatives[negatives != val]
        choice = np.random.choice(rest, size=size, replace=False)
        choices.append(choice)

    return np.stack(choices).squeeze()

# %% [markdown]
# # Load Data

# %%
group = 'biomedical'

# %%
site = 'biology'
qdf = pd.read_csv(f'/kaggle/input/stackexchange-raw-qa/{group}/{site}_questions.csv')
adf = pd.read_csv(f'/kaggle/input/stackexchange-raw-qa/{group}/{site}_answers.csv')

qdf.Body = qdf.Body.apply(clean)
adf.Body = adf.Body.apply(clean)

# %% [markdown]
# # First find the good and bad answers
#
# The good answers are the ones that have a score of 2 or more. the bad one have a score of 0 or less.

# %%
accepted_answer_ids = qdf.AcceptedAnswerId.dropna().unique()

# %%
best_answers = (
    adf
    .sort_values(by=['Score'], ascending=False)
    .drop_duplicates('ParentId')
    .query("Score > 1")
)
print(best_answers.shape)

bad_answers = (
    adf
    .loc[~adf.Id.isin(accepted_answer_ids)] # An accepted answer can't be bad
    .sort_values(by=['Score'], ascending=True) # Take the one with the worst score
    .drop_duplicates('ParentId') # Drop every other options
    .query("Score < 1")
    .loc[:, ['ParentId', 'Body']]
    .rename(columns={'Body': 'WrongAnswer'})   
)
bad_answers['WrongAnswerType'] = 'Bad Answers'
print(bad_answers.shape)
# Out:
# (13406, 6)
# (2796, 3)

# %% [markdown]
# # Merge with Accepted answers
#
# If a question has an accepted answer, we merge that answer with the question dataframe.

# %%
accepted = (
    qdf.merge(
        adf, how='inner', 
        left_on='AcceptedAnswerId', right_on='Id', 
        suffixes=("Question", "Answer"))
    .drop(columns=['ParentId', 'AcceptedAnswerId'])
)
accepted['AnswerType'] = 'Accepted'
print(accepted.shape)
accepted.head()
# Out:
# (10522, 12)
#    IdQuestion                                              Title  \
# 0       13408  Why are interspecies hybrids so often larger t...
# 1       13412                               Body's decomposition
# 2       13414                 A weird-looking fish with a shield
# 3       13421  Why does caffeine consumption cause one to uri...
# 4       13425             Telomere shortening during replication
#
#                                         BodyQuestion CreationDateQuestion  \
# 0  Recently doing a little reading on interspecie...  2013-11-10 03:15:02
# 1  Does a human body decompose in a completely st...  2013-11-10 12:12:54
# 2  I found this photo in a local news page. The p...  2013-11-10 17:01:13
# 3  What is the physiological mechanism behind the...  2013-11-11 07:23:27
# 4  It is widely know that each cell cycle during ...  2013-11-11 12:49:24
#
#    ScoreQuestion  OwnerUserIdQuestion  IdAnswer  \
# 0              5               4884.0     13409
# 1              1               4889.0     13424
# 2             17                  NaN     13443
# 3              4               1472.0     13431
# 4              3               3657.0     13434
#
#                                           BodyAnswer   CreationDateAnswer  \
# 0  While they do not necessarily constitute the m...  2013-11-10 03:59:39
# 1  \n  Does a human body decompose in a completel...  2013-11-11 12:07:13
# 2  The front part of the fish looks like part of ...  2013-11-12 08:40:36
# 3  Caffeine inhibits the secretion of the antidiu...  2013-11-11 17:32:45
# 4  In replication, both the chromosomal halves (w...  2013-11-11 18:46:42
#
#    ScoreAnswer  OwnerUserIdAnswer AnswerType
# 0            4             4882.0   Accepted
# 1            1             3340.0   Accepted
# 2           11             1486.0   Accepted
# 3            6             4025.0   Accepted
# 4            3             3615.0   Accepted

# %% [markdown]
# # Merge with Reasonable Answers
#
# If a question doesn't have an accepted answer, we merge the question dataframe with the best (most upvoted) answer available.

# %%
reasonable = (
    qdf
    .loc[qdf.AcceptedAnswerId.isna()]
    .merge(
        best_answers, how='inner', 
        left_on='Id', right_on='ParentId', 
        suffixes=("Question", "Answer"))
    .drop(columns=['ParentId', 'AcceptedAnswerId'])
)
reasonable['AnswerType'] = 'Reasonable'
print(reasonable.shape)
reasonable.head()
# Out:
# (5032, 12)
#    IdQuestion                                              Title  \
# 0       13415  What makes a DNA sequence motif a DNA sequence...
# 1       13416                   Why are antibodies so expensive?
# 2       13418  Why is the 4.4 kb band barely visible in this ...
# 3       13420  explanation of conjugation experiment in bacteria
# 4       13436    Why can CO₂ be transported dissolved in plasma?
#
#                                         BodyQuestion CreationDateQuestion  \
# 0  I've read about DNA sequence motifs, but still...  2013-11-10 19:46:14
# 1  The amplification on vector transgenic microor...  2013-11-10 19:52:47
# 2  Why is the 4.4 kb band barely visible? \n\nAls...  2013-11-10 22:34:27
# 3  In this paper (On the expression of a structur...  2013-11-11 00:37:00
# 4  Is it because CO2 is more soluble in water or ...  2013-11-11 19:09:15
#
#    ScoreQuestion  OwnerUserIdQuestion  IdAnswer  \
# 0              7                284.0     13422
# 1              3               3657.0     14079
# 2              1               4892.0     13428
# 3              1               1693.0     13437
# 4              1               3615.0     13450
#
#                                           BodyAnswer   CreationDateAnswer  \
# 0  Motif means a pattern. For any array of object...  2013-11-11 07:56:45
# 1  Making antibodies is mostly nothing you do wit...  2013-12-20 08:04:32
# 2  First of all, the 4.4 kb HindIII band is deriv...  2013-11-11 14:35:21
# 3  There are three variables being shown here: \n...  2013-11-11 23:02:20
# 4  The bulk of CO2 is transported as bicarbonate/...  2013-11-12 14:19:00
#
#    ScoreAnswer  OwnerUserIdAnswer  AnswerType
# 0            4             3340.0  Reasonable
# 1            6             5144.0  Reasonable
# 2            2             1320.0  Reasonable
# 3            2             4840.0  Reasonable
# 4            3             4908.0  Reasonable

# %% [markdown]
# # Combine results
#
# Now, we combine both the accepted qa dataframe with the reasonable qa dataframe. We will also merge that combined dataframe with the bad answers we defined earlier, so that we have both a correct (accepted) and incorrect (low votes) answer for every question. Note that the new wrong answer column will have missing values; this will be corrected in the next cell.

# %%
combined = pd.concat([accepted, reasonable]).reset_index(drop=True)
combined = (
    combined
    .merge(
        bad_answers, how='left',
        left_on='IdQuestion', right_on='ParentId')
    .drop(columns=['ParentId'])
)

# %% [markdown]
# Since not all qa pairs will have a "bad" answer, for the rows were the "wrong answer" is missing, we randomly sample a negative example from the set of answers.

# %%
unique_ans = adf.drop_duplicates('ParentId')
negative_ids = negative_sampling(combined.IdQuestion.values, unique_ans.ParentId.values)

wrong_answers = (
    unique_ans.set_index("ParentId")
    .loc[negative_ids, 'Body']
    .reset_index(drop=True)
)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=15554.0), HTML(value='')))

# %%
combined.WrongAnswerType.fillna("Random", inplace=True)
combined.WrongAnswer.fillna(wrong_answers, inplace=True)

# %% [markdown]
# # Post processing
#
# Rename columns, remove columns that are not useful

# %%
combined['site'] = site

# %%
combined.drop(
    columns=[
        'CreationDateQuestion', 'ScoreQuestion', 
        'OwnerUserIdQuestion', 'CreationDateAnswer', 
        'ScoreAnswer'
    ], inplace=True
)

# %%
combined.rename(inplace=True, columns={
    'IdQuestion': 'question_id',
    'Title': 'title',
    'BodyQuestion': 'question',
    'IdAnswer': 'answer_id',
    'BodyAnswer': 'answer',
    'WrongAnswer': 'wrong_answer',
    'AnswerType': 'answer_type',
    'WrongAnswerType': 'wrong_answer_type'
})

# %% [markdown]
# # Preprocess all stackexchange

# %%
def process_qa_dataframes(qdf, adf, site):
    """
    given a question and an answer dataframes, we process them 
    and combine them, then add negative answers, and format it.
    """
    accepted_answer_ids = qdf.AcceptedAnswerId.dropna().unique()

    best_answers = (
        adf
        .sort_values(by=['Score'], ascending=False)
        .drop_duplicates('ParentId')
        .query("Score > 1")
    )

    bad_answers = (
        adf
        .loc[~adf.Id.isin(accepted_answer_ids)] # An accepted answer can't be bad
        .sort_values(by=['Score'], ascending=True) # Take the one with the worst score
        .drop_duplicates('ParentId') # Drop every other options
        .query("Score < 1")
        .loc[:, ['ParentId', 'Body']]
        .rename(columns={'Body': 'WrongAnswer'})   
    )
    bad_answers['WrongAnswerType'] = 'Bad Answers'

    # Merge with Accepted answers
    accepted = (
        qdf.merge(
            adf, how='inner', 
            left_on='AcceptedAnswerId', right_on='Id', 
            suffixes=("Question", "Answer"))
        .drop(columns=['ParentId', 'AcceptedAnswerId'])
    )
    accepted['AnswerType'] = 'Accepted'

    # Merge with Reasonable Answers
    reasonable = (
        qdf
        .loc[qdf.AcceptedAnswerId.isna()]
        .merge(
            best_answers, how='inner', 
            left_on='Id', right_on='ParentId', 
            suffixes=("Question", "Answer"))
        .drop(columns=['ParentId', 'AcceptedAnswerId'])
    )
    reasonable['AnswerType'] = 'Reasonable'

    # Combine results
    combined = pd.concat([accepted, reasonable]).reset_index(drop=True)
    combined = (
        combined
        .merge(
            bad_answers, how='left',
            left_on='IdQuestion', right_on='ParentId')
        .drop(columns=['ParentId'])
    )
    
    # Random sampling for rows that do not have "bad" answers
    unique_ans = adf.drop_duplicates('ParentId')
    negative_ids = negative_sampling(combined.IdQuestion.values, unique_ans.ParentId.values)

    wrong_answers = (
        unique_ans.set_index("ParentId")
        .loc[negative_ids, 'Body']
        .reset_index(drop=True)
    )

    combined.WrongAnswerType.fillna("Random", inplace=True)
    combined.WrongAnswer.fillna(wrong_answers, inplace=True)

    # Post processing
    combined['site'] = site

    combined.drop(
        columns=[
            'CreationDateQuestion', 'ScoreQuestion', 
            'OwnerUserIdQuestion', 'CreationDateAnswer', 
            'ScoreAnswer', 'OwnerUserIdAnswer'
        ], inplace=True
    )

    combined.rename(inplace=True, columns={
        'IdQuestion': 'question_id',
        'Title': 'title',
        'BodyQuestion': 'question',
        'IdAnswer': 'answer_id',
        'BodyAnswer': 'answer',
        'WrongAnswer': 'wrong_answer',
        'AnswerType': 'answer_type',
        'WrongAnswerType': 'wrong_answer_type'
    })
    
    return combined

# %% [markdown]
# # Process each group

# %%
dfs = {}
for group in ['biomedical', 'expert', 'general']:
    sites = list(set([x.split("_")[0] for x in os.listdir(f'/kaggle/input/stackexchange-raw-qa/{group}/')]))

    combined_ls = []

    for site in tqdm(sites, desc=group):
        qdf = pd.read_csv(f'/kaggle/input/stackexchange-raw-qa/{group}/{site}_questions.csv')
        adf = pd.read_csv(f'/kaggle/input/stackexchange-raw-qa/{group}/{site}_answers.csv')

        qdf.Body = qdf.Body.apply(clean)
        adf.Body = adf.Body.apply(clean)

        combined = process_qa_dataframes(qdf, adf, site)
        combined_ls.append(combined)

    all_df = pd.concat(combined_ls)
    dfs[group] = all_df
# Out:
# HBox(children=(FloatProgress(value=0.0, description='biomedical', max=3.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, max=15554.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=3367.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1976.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, description='expert', max=12.0, style=ProgressStyle(description_width=…
# HBox(children=(FloatProgress(value=0.0, max=6587.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=16405.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10649.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8794.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=4385.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22656.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=22318.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=9922.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=7980.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14371.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=5532.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10419.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, description='general', max=16.0, style=ProgressStyle(description_width…
# HBox(children=(FloatProgress(value=0.0, max=6739.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=4142.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=5503.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=3334.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=3380.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=18551.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=3531.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=6303.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=16783.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10665.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=4624.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10125.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=8316.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=9188.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12537.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=9473.0), HTML(value='')))

# %%
for group in ['biomedical', 'expert', 'general']:
    df = dfs[group]
    text = df.question.str.lower() + df.title.str.lower() + df.answer.str.lower()

    mask = (
        text.str.contains('covid') |
        text.str.contains('coronavirus') |
        text.str.contains('corona virus') |
        text.str.contains('2019-ncov') |
        text.str.contains('2019 ncov') |
        text.str.contains('sars-cov') |
        text.str.contains('sars cov')
    )
    
    df['group'] = group
    df[mask].to_csv(f"covid/{group}.csv")
    df[~mask].to_csv(f"pre_covid/{group}.csv")
    print(df[mask].shape)
# Out:
# (196, 10)
# (146, 10)
# (300, 10)

# %%
dfs
# Out:
# {'biomedical':       question_id                                              title  \
#  0           13408  Why are interspecies hybrids so often larger t...
#  1           13412                               Body's decomposition
#  2           13414                 A weird-looking fish with a shield
#  3           13421  Why does caffeine consumption cause one to uri...
#  4           13425             Telomere shortening during replication
#  ...           ...                                                ...
#  1971         7292  Pipeline for extracting gene from multiple gen...
#  1972         7305  Differential expression analysis when nested e...
#  1973         7311  How to extract gene expression tables from thi...
#  1974         7318  RNA-seq analysis of mixed viral/host reads wit...
#  1975        11345  How to translate amino acid sequences to Nucle...
#
#                                                 question  answer_id  \
#  0     Recently doing a little reading on interspecie...      13409
#  1     Does a human body decompose in a completely st...      13424
#  2     I found this photo in a local news page. The p...      13443
#  3     What is the physiological mechanism behind the...      13431
#  4     It is widely know that each cell cycle during ...      13434
#  ...                                                 ...        ...
#  1971  I have been trying to obtain some preliminary ...       7296
#  1972  I have 3 tumour samples from 3 patients from a...       7306
#  1973  I've downloaded this GSE43013 dataset using GE...       7316
#  1974  I did RNA-seq of mammalian cells infected with...       7319
#  1975  I want to convert a list of fasta ( protein se...      11352
#
#                                                   answer answer_type  \
#  0     While they do not necessarily constitute the m...    Accepted
#  1     \n  Does a human body decompose in a completel...    Accepted
#  2     The front part of the fish looks like part of ...    Accepted
#  3     Caffeine inhibits the secretion of the antidiu...    Accepted
#  4     In replication, both the chromosomal halves (w...    Accepted
#  ...                                                 ...         ...
#  1971  Okay well, because you're using HYPHY, you're ...  Reasonable
#  1972  llrs is right.  "Matrix Model not full rank" m...  Reasonable
#  1973  Assuming that you have downloaded processed fi...  Reasonable
#  1974  You provide Salmon with a transcriptome fasta....  Reasonable
#  1975  Although there is not a unique nucleotide sequ...  Reasonable
#
#                                             wrong_answer wrong_answer_type  \
#  0     My initial guess (knowing almost no informatio...            Random
#  1     In the pictures shown above only the soft part...            Random
#  2     The delay in immune attack is common for many ...            Random
#  3     Short answer\nThe dopamine hypothesis includes...            Random
#  4     To expand on my comments:\n\nJust like you men...            Random
#  ...                                                 ...               ...
#  1971  TRAL 0.3.5 has bugs running and parsing Phobos...            Random
#  1972  Seurat is expecting individual datasets to be ...            Random
#  1973  I would agree with your statement.  Typically ...            Random
#  1974  The "identities" can be accessed with the Iden...            Random
#  1975  Don't use Wine at all! You seem to be running ...            Random
#
#                  site       group
#  0            biology  biomedical
#  1            biology  biomedical
#  2            biology  biomedical
#  3            biology  biomedical
#  4            biology  biomedical
#  ...              ...         ...
#  1971  bioinformatics  biomedical
#  1972  bioinformatics  biomedical
#  1973  bioinformatics  biomedical
#  1974  bioinformatics  biomedical
#  1975  bioinformatics  biomedical
#
#  [20897 rows x 10 columns],
#  'expert':        question_id                                              title  \
#  0           398847  How to show UML component load/discovery and r...
#  1           398849         Queue management project - Recommendations
#  2           398856  Why is it bad to map between a Model and a Vie...
#  3           398857  Managing sprints for multiple releases of the ...
#  4           398863  Does references between entities of the same a...
#  ...            ...                                                ...
#  10414         8707  Text-Classification-Problem: Is Word2Vec/NN th...
#  10415         8709  Using non-negative matrix factorization (NMF) ...
#  10416         8809  What is an interpretation of the $\,f'\!\left(...
#  10417         8811  Improving SVM binary classification model on n...
#  10418         8820  Unbalanced classes -- How to minimize false ne...
#
#                                                  question  answer_id  \
#  0      In a UML component diagram I want to show two ...     398923
#  1      I would like to develop a Patient Queue manage...     398889
#  2      In a recent Pull Request (PR) of mine, a colle...     398858
#  3      How do you plan a sprint for the same product ...     398888
#  4      Consider an application being implemented foll...     398866
#  ...                                                  ...        ...
#  10414  I am looking to design a system that given a p...       8721
#  10415  I'm interested to find out how to implement NM...       8720
#  10416  In the $\delta$-rule which is used for error b...       8817
#  10417  I am working to create a SVM binary classifier...       8815
#  10418  I have a dataset that has a binary class attri...       8821
#
#                                                    answer answer_type  \
#  0      Your first diagram is not correct. Arrow A wou...    Accepted
#  1      Design issue\n\nIn reality you have two very d...    Accepted
#  2      \n  It isn't how extension methods are suppose...    Accepted
#  3      Sprints are different than releases. Although ...    Accepted
#  4      To your question: "Does the usage of these ref...    Accepted
#  ...                                                  ...         ...
#  10414  1) Max-Entropy(Logistic Regression) on TFIDF v...  Reasonable
#  10415  One major issue with this approach is that if ...  Reasonable
#  10416  The equation that you show calculates (the neg...  Reasonable
#  10417  Online learning for SVMs is supported only for...  Reasonable
#  10418  Class imbalance is a very common problem.  You...  Reasonable
#
#                                              wrong_answer wrong_answer_type  \
#  0      This way, the dates can easily be sorted as st...            Random
#  1      If the capabilities of your new ISA are simila...            Random
#  2      You can do all the basic validation on client-...            Random
#  3      Create a repository to wrap whatever stores yo...            Random
#  4      I would do the second option but allow the use...            Random
#  ...                                                  ...               ...
#  10414  You can simply generate them yourself. They ar...            Random
#  10415  NMF and PCA are very similar such that both ar...       Bad Answers
#  10416  Think of this problem as a pipeline of steps t...            Random
#  10417  One way to do this is by following the indicat...            Random
#  10418  Under- and over-sampling as a technique have a...       Bad Answers
#
#                site   group
#  0      programmers  expert
#  1      programmers  expert
#  2      programmers  expert
#  3      programmers  expert
#  4      programmers  expert
#  ...            ...     ...
#  10414  datascience  expert
#  10415  datascience  expert
#  10416  datascience  expert
#  10417  datascience  expert
#  10418  datascience  expert
#
#  [140018 rows x 10 columns],
#  'general':       question_id                                              title  \
#  0           18276  Questions on the effectiveness and safety of w...
#  1           18282   Is it possible to lose 3 pounds of FAT per week?
#  2           18293  Does sitting for longer hours really have an e...
#  3           18296         How to identify what type of body is yours
#  4           18309                    Muscle mass with dumbbells only
#  ...           ...                                                ...
#  9468       124424                         Tourist visa Schengen Zone
#  9469       124435  Do the seat rows across the aisle from the Cat...
#  9470       124446  Will bringing my mother in visitor visa to Ger...
#  9471       124460  Can anyone please clarify my doubts regarding ...
#  9472       124475  Does a Canadian citizen need a visa for a stop...
#
#                                                 question  answer_id  \
#  0     I recently stopped doing front squats due to b...      18290
#  1     I have a lot of fat lose. I weigh 210 pounds, ...      18285
#  2     After going through this link I am confused ab...      18297
#  3     I agree that different exercise suits for diff...      18298
#  4     Last summer I didn't have a job and had a lot ...      22363
#  ...                                                 ...        ...
#  9468  Trying to find the answer to this but all of t...     124426
#  9469  The economy rows in the picture on seat guru d...     124438
#  9470  I am planning to bring my mother in visitor vi...     124447
#  9471  I am from India and been working (as a graphic...     124496
#  9472  I have a 14-hour layover in New Zealand before...     124478
#
#                                                   answer answer_type  \
#  0     \nDOMS is not directly indicative of how effec...    Accepted
#  1     Yes, its theoretically possible. Are you going...    Accepted
#  2     It appears that this article is aimed more at ...    Accepted
#  3     Stop. Drop this idea that you 'have a body typ...    Accepted
#  4     Of course there is. You can do bodybuilding at...    Accepted
#  ...                                                 ...         ...
#  9468  \n  How does this work with the rolling 180 da...  Reasonable
#  9469  Here is the official Cathay Pacific seating ma...  Reasonable
#  9470  It is always hard to predict how authorities w...  Reasonable
#  9471  If you need to visit Australia for holidays, y...  Reasonable
#  9472  Canada is on New Zealand’s list of visa waiver...  Reasonable
#
#                                             wrong_answer wrong_answer_type  \
#  0     I'm a beginner (40 years old) who started runn...            Random
#  1     Welcome to the Fitness SE!\n\nMaking your own ...            Random
#  2     There is a myth that exercise increases the se...            Random
#  3     Your original statement is not correct. Deadli...            Random
#  4     The more repetitions you can do, the more you ...            Random
#  ...                                                 ...               ...
#  9468  In general it's best to talk in terms of "Band...            Random
#  9469  This page says of West Mersea\n\n\nSurf Condit...            Random
#  9470  The Mauna Kea Visitor Center is well below the...            Random
#  9471  The correct course of action here is to change...            Random
#  9472  When you arrive at Frankfurt from India and im...            Random
#
#           site    group
#  0     fitness  general
#  1     fitness  general
#  2     fitness  general
#  3     fitness  general
#  4     fitness  general
#  ...       ...      ...
#  9468   travel  general
#  9469   travel  general
#  9470   travel  general
#  9471   travel  general
#  9472   travel  general
#
#  [133194 rows x 10 columns]}
